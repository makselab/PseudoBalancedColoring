# %%
# %%javascript
#
# IPython.tab_as_tab_everywhere = function(use_tabs) {
#     if (use_tabs === undefined) {
#         use_tabs = true;
#     }
#
#     // apply setting to all current CodeMirror instances
#     IPython.notebook.get_cells().map(
#         function(c) {  return c.code_mirror.options.indentWithTabs=use_tabs;  }
#     );
#     // make sure new CodeMirror instances created in the future also use this setting
#     CodeMirror.defaults.indentWithTabs=use_tabs;
#
#     };
#
# IPython.tab_as_tab_everywhere()

# %%
from functions import *

folderToRun = "../DATA/INTEGER-PROGRAM-COST-EDGES/INPUT/c_bw_no_05_12"
outputFolder = "../DATA/INTEGER-PROGRAM-COST-EDGES/OUTPUT/c_bw_no_05_12"
#folderToRun = "../DATA/INTEGER-PROGRAM-COST-EDGES/INPUT/c_fw_no_07_06"
#outputFolder = "../DATA/INTEGER-PROGRAM-COST-EDGES/OUTPUT/c_fw_no_07_06"
#folderToRun = "../DATA/INTEGER-PROGRAM-COST-ONE-OVER-MAX-DEGREE/INPUT/c_bw_no_05_19"
#outputFolder = "../DATA/INTEGER-PROGRAM-COST-ONE-OVER-MAX-DEGREE/OUTPUT/c_bw_no_05_19"
#folderToRun = "../DATA/INTEGER-PROGRAM-COST-ONE-OVER-MAX-DEGREE/INPUT/c_fw_no_05_19"
#outputFolder = "../DATA/INTEGER-PROGRAM-COST-ONE-OVER-MAX-DEGREE/OUTPUT/c_fw_no_05_19"
#folderToRun = "../DATA/INTEGER-PROGRAM-COST-ONE-OVER-SUM-DEGREES/INPUT/c_bw_no_sum_05_21"
#outputFolder = "../DATA/INTEGER-PROGRAM-COST-ONE-OVER-SUM-DEGREES/OUTPUT/c_bw_no_sum_05_21"
#folderToRun = "../DATA/INTEGER-PROGRAM-COST-ONE-OVER-SUM-DEGREES/INPUT/c_fw_no_sum_07_02"
#outputFolder = "../DATA/INTEGER-PROGRAM-COST-ONE-OVER-SUM-DEGREES/OUTPUT/c_fw_no_sum_07_02"
#folderToRun = "../DATA/INTEGER-PROGRAM-COST-ONE-OVER-MULTI-DEGREE/INPUT/c_fw_no"
#outputFolder = "../DATA/INTEGER-PROGRAM-COST-ONE-OVER-MULTI-DEGREE/OUTPUT/c_fw_no"
#folderToRun = "../DATA/INTEGER-PROGRAM-COST-ONE-OVER-MULTI-DEGREE/INPUT/c_bw_no"
#outputFolder = "../DATA/INTEGER-PROGRAM-COST-ONE-OVER-MULTI-DEGREE/OUTPUT/c_bw_no"

runFolder(folderToRun, outputFolder)
# Out:
# Running  ../DATA/INTEGER-PROGRAM-COST-EDGES/INPUT/c_bw_no_05_12/run_c_bw_no_nc_8.txt
# Running  ../DATA/INTEGER-PROGRAM-COST-EDGES/INPUT/c_bw_no_05_12/run_c_bw_no_nc_14.txt
# Running  ../DATA/INTEGER-PROGRAM-COST-EDGES/INPUT/c_bw_no_05_12/run_c_bw_no_nc_12.txt
# Running  ../DATA/INTEGER-PROGRAM-COST-EDGES/INPUT/c_bw_no_05_12/run_c_bw_no_nc_9.txt
# Running  ../DATA/INTEGER-PROGRAM-COST-EDGES/INPUT/c_bw_no_05_12/run_c_bw_no_nc_13.txt
# Running  ../DATA/INTEGER-PROGRAM-COST-EDGES/INPUT/c_bw_no_05_12/run_c_bw_no_nc_6.txt
# Running  ../DATA/INTEGER-PROGRAM-COST-EDGES/INPUT/c_bw_no_05_12/run_c_bw_no_nc_17.txt
# Running  ../DATA/INTEGER-PROGRAM-COST-EDGES/INPUT/c_bw_no_05_12/run_c_bw_no_nc_16.txt
# Running  ../DATA/INTEGER-PROGRAM-COST-EDGES/INPUT/c_bw_no_05_12/run_c_bw_no_nc_10.txt
# Running  ../DATA/INTEGER-PROGRAM-COST-EDGES/INPUT/c_bw_no_05_12/run_c_bw_no_nc_7.txt
# Running  ../DATA/INTEGER-PROGRAM-COST-EDGES/INPUT/c_bw_no_05_12/run_c_bw_no_nc_11.txt
# ...

# %%
from functions import *

foldersToRun = ["../DATA/INTEGER-PROGRAM-COST-EDGES/INPUT/c_bw_no_05_12",
				"../DATA/INTEGER-PROGRAM-COST-EDGES/INPUT/c_fw_no_07_06",
				"../DATA/INTEGER-PROGRAM-COST-ONE-OVER-MAX-DEGREE/INPUT/c_bw_no_05_19",
				"../DATA/INTEGER-PROGRAM-COST-ONE-OVER-MAX-DEGREE/INPUT/c_fw_no_05_19",
				"../DATA/INTEGER-PROGRAM-COST-ONE-OVER-SUM-DEGREES/INPUT/c_bw_no_sum_05_21",
				"../DATA/INTEGER-PROGRAM-COST-ONE-OVER-SUM-DEGREES/INPUT/c_fw_no_sum_07_02",
				"../DATA/INTEGER-PROGRAM-COST-ONE-OVER-MULTI-DEGREE/INPUT/c_fw_no",
				"../DATA/INTEGER-PROGRAM-COST-ONE-OVER-MULTI-DEGREE/INPUT/c_bw_no"]
outputFolders = ["../DATA/INTEGER-PROGRAM-COST-EDGES/OUTPUT/c_bw_no_05_12",
				 "../DATA/INTEGER-PROGRAM-COST-EDGES/OUTPUT/c_fw_no_07_06",
				 "../DATA/INTEGER-PROGRAM-COST-ONE-OVER-MAX-DEGREE/OUTPUT/c_bw_no_05_19",
				 "../DATA/INTEGER-PROGRAM-COST-ONE-OVER-MAX-DEGREE/OUTPUT/c_fw_no_05_19",
				 "../DATA/INTEGER-PROGRAM-COST-ONE-OVER-SUM-DEGREES/OUTPUT/c_bw_no_sum_05_21",
				 "../DATA/INTEGER-PROGRAM-COST-ONE-OVER-SUM-DEGREES/OUTPUT/c_fw_no_sum_07_02",
				 "../DATA/INTEGER-PROGRAM-COST-ONE-OVER-MULTI-DEGREE/OUTPUT/c_fw_no",
				 "../DATA/INTEGER-PROGRAM-COST-ONE-OVER-MULTI-DEGREE/OUTPUT/c_bw_no"]

for i in range(len(foldersToRun)):
	runFolder(foldersToRun[i], outputFolders[i])
# Out:
# Running  ../DATA/INTEGER-PROGRAM-COST-EDGES/INPUT/c_bw_no_05_12/run_c_bw_no_nc_8.txt
# Running  ../DATA/INTEGER-PROGRAM-COST-EDGES/INPUT/c_bw_no_05_12/run_c_bw_no_nc_14.txt
# Running  ../DATA/INTEGER-PROGRAM-COST-EDGES/INPUT/c_bw_no_05_12/run_c_bw_no_nc_12.txt
# Running  ../DATA/INTEGER-PROGRAM-COST-EDGES/INPUT/c_bw_no_05_12/run_c_bw_no_nc_9.txt
# Running  ../DATA/INTEGER-PROGRAM-COST-EDGES/INPUT/c_bw_no_05_12/run_c_bw_no_nc_13.txt
# Running  ../DATA/INTEGER-PROGRAM-COST-EDGES/INPUT/c_bw_no_05_12/run_c_bw_no_nc_6.txt
# Running  ../DATA/INTEGER-PROGRAM-COST-EDGES/INPUT/c_bw_no_05_12/run_c_bw_no_nc_17.txt
# Running  ../DATA/INTEGER-PROGRAM-COST-EDGES/INPUT/c_bw_no_05_12/run_c_bw_no_nc_16.txt
# Running  ../DATA/INTEGER-PROGRAM-COST-EDGES/INPUT/c_bw_no_05_12/run_c_bw_no_nc_10.txt
# Running  ../DATA/INTEGER-PROGRAM-COST-EDGES/INPUT/c_bw_no_05_12/run_c_bw_no_nc_7.txt
# Running  ../DATA/INTEGER-PROGRAM-COST-EDGES/INPUT/c_bw_no_05_12/run_c_bw_no_nc_11.txt
# ...

# %%
from functions import *

fileName = "test/test.txt"
#fileName = "../DATA/INTEGER-PROGRAM-COST-EDGES/INPUT/c_bw_no_05_12/run_c_bw_no_nc_10.txt"

runFile(fileName)
# Out:
# Running  test/test.txt
#   Id Label Orbit IPColor  Fixed  Sector
# 2  b     b   1_0       2  False       1
# 4  d     d   1_0       2  False       1
# 0  a     a   2_0       1  False       2
# 1  c     c   2_1       3  False       2
# 3  e     e   2_1       4  False       2
# Fiedler value =  1.9999999999999998
# Normalized Fiedler value =  1.0
# Eigen ratio =  0.3999999999999998
# Mean epsilon =  5.0
# Max epsilon =  8.0
# Randic Index =  5.0
# Average Path Length =  1.3
# Average Clustering Coefficient =  0.8
#
# Class:
# 	 S2
# Mean epsilon = 	 8.0
# Max epsilon = 	 8.0
# Sector:
# 	 ['c', 'e']
# Orbits ( 1 ):
# 	 0 :	 ['c', 'e']
# Permutations:
# 	Epsilon =  8.0 :	 [['c', 'e']]
#
# Class:
# 	 S3
# Mean epsilon = 	 2.0
# Max epsilon = 	 4.0
# Sector:
# 	 ['a', 'b', 'd']
# Orbits ( 1 ):
# 	 0 :	 ['a', 'b', 'd']
# Permutations:
# 	Epsilon =  4.0 :	 [['b', 'd']]
# 	Epsilon =  0.0 :	 [['a', 'b']]

# %%
from functions import *

fileName = "test/test3.txt"

edges = readEdgeFile(fileName)
symmetryAnalyzer = SymmetryAnalyzer(edges, directed = True)
symmetryAnalyzer.decompose()
symmetryAnalyzer.calculate_indices()
symmetryAnalyzer.print_all_info()
# Out:
#   Id Label Orbit  Sector
# 0  a     a   1_0       1
# 1  c     c   1_1       1
# 2  b     b   2_0       2
# 4  d     d   3_4       3
# 3  e     e   4_3       4
# Fiedler value =  1.0
# Normalized Fiedler value =  1.0
# Eigen ratio =  0.5
# Mean epsilon =  0.0
# Max epsilon =  0.0
# Randic Index =  7.371320343559644
# Average Path Length =  1.2222222222222223
# Average Clustering Coefficient =  0.8
#
# Class:
# 	 S2
# Mean epsilon = 	 0.0
# Max epsilon = 	 0.0
# Sector:
# 	 ['a', 'b']
# Orbits ( 1 ):
# 	 0 :	 ['a', 'b']
# Permutations:
# 	Epsilon =  0.0 :	 [['a', 'b']]
